# %% [markdown]
# Machine Learning Regresion Logistica

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('matriculados_costos.csv')
df.head()
# Out:
#   AlumonosMatriculados CostosAnuales
# 0               11,376     84,960.00
# 1               20,000     52,042.00
# 2               26,455        61,908
# 3               57,261     74,463.00
# 4               21,656     22,972.00

# %%
df.describe()
# Out:
#        AlumonosMatriculados CostosAnuales
# count                   149           149
# unique                  143            74
# top                  30,000        40,000
# freq                      4            15

# %%
# Crear un gráfico de dispersión
plt.scatter(df['AlumonosMatriculados'], df['CostosAnuales'])
plt.xlabel('Alumnos Matriculados')
plt.ylabel('Costos Anuales')
plt.title('Relación entre Alumnos Matriculados y Costos Anuales')

# Mostrar el gráfico
plt.show()
